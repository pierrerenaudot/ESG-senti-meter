# %%
import os
from dotenv import load_dotenv

load_dotenv()

apikey = os.getenv('GNEWS_API_KEY')
category = 'business'
url = f"https://gnews.io/api/v4/top-headlines?category={category}&lang=en&country=us&max=10&apikey={apikey}"

# with urllib.request.urlopen(url) as response:
#     data = json.loads(response.read().decode("utf-8"))
# print(json.dumps(data, indent=4))

# %%
# In this section we are opening the news dataset we are going to analyse

import pandas as pd

# dataset containing +30000 news articles related to environmental topic
df = pd.read_csv('./datasets/guardian_environment_news.csv')
